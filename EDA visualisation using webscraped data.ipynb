# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("C:\\Users\\Sriram\\mobile_details.csv")

# %%
df
# Out:
#      Unnamed: 0    Brand    Model_Name            colour  \
# 0             0     POCO       POCO M3      (Power Black
# 1             1    REDMI      REDMI 9i   (Midnight Black
# 2             2  Infinix   Infinix Hot      (Aegean Blue
# 3             3   realme  realme Narzo      (Laser Black
# 4             4   realme  realme Narzo      (Laser Black
# ..          ...      ...           ...               ...
# 547         547   GIONEE    GIONEE Max               NaN
# 548         548   realme    realme C12       (Power Blue
# 549         549    REDMI       REDMI 9   (Electric Green
# 550         550   realme    realme C25      (Watery Blue
# 551         551     POCO       POCO M3        (Cool Blue
#
#                        Processor  RAM_in_GB  ROM_in_GB Expandable_Memory  \
# 0       Snapdragon 662 Processor          6         64            512 GB
# 1            Helio G25 Processor          4         64            512 GB
# ...

# %%
df.shape
# Out:
# (552, 13)

# %%
df.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0    Brand    Model_Name            colour  \
# 0             0     POCO       POCO M3      (Power Black
# 1             1    REDMI      REDMI 9i   (Midnight Black
# 2             2  Infinix   Infinix Hot      (Aegean Blue
# 3             3   realme  realme Narzo      (Laser Black
# 4             4   realme  realme Narzo      (Laser Black
# ..          ...      ...           ...               ...
# 547         547   GIONEE    GIONEE Max               NaN
# 548         548   realme    realme C12       (Power Blue
# 549         549    REDMI       REDMI 9   (Electric Green
# 550         550   realme    realme C25      (Watery Blue
# 551         551     POCO       POCO M3        (Cool Blue
#
#                        Processor  RAM_in_GB  ROM_in_GB Expandable_Memory  \
# 0       Snapdragon 662 Processor          6         64            512 GB
# 1            Helio G25 Processor          4         64            512 GB
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# Brand                 object
# Model_Name            object
# colour                object
# Processor             object
# RAM_in_GB              int64
# ROM_in_GB              int64
# Expandable_Memory     object
# Battery_in_mAh         int64
# Camera                object
# Display_in_cm        float64
# Rating               float64
# Price                float64
# dtype: object

# %%
df.describe()
# Out:
#        Unnamed: 0   RAM_in_GB   ROM_in_GB  Battery_in_mAh  Display_in_cm  \
# count  552.000000  552.000000  552.000000      552.000000     552.000000
# mean   275.500000    3.742754   54.782609     5621.376812      16.596196
# std    159.492947    1.095670   22.116582      485.483937       0.352117
# min      0.000000    2.000000   32.000000     5000.000000      15.490000
# 25%    137.750000    3.000000   32.000000     5000.000000      16.510000
# 50%    275.500000    4.000000   64.000000     6000.000000      16.550000
# 75%    413.250000    4.000000   64.000000     6000.000000      16.590000
# max    551.000000    6.000000  128.000000     6000.000000      17.320000
#
#            Rating         Price
# count  552.000000    552.000000
# mean     4.336413   8829.797101
# std      0.071006   1471.370122
# min      4.100000   5499.000000
# 25%      4.300000   7999.000000
# 50%      4.300000   8499.000000
# 75%      4.400000   9624.000000
# max      4.400000  11999.000000

# %%
## Here I'm dropping unamed column as it gives me same values of my index

# %%
df.drop(columns="Unnamed: 0",inplace=True)

# %%
df
# Out:
#        Brand    Model_Name            colour                    Processor  \
# 0       POCO       POCO M3      (Power Black     Snapdragon 662 Processor
# 1      REDMI      REDMI 9i   (Midnight Black          Helio G25 Processor
# 2    Infinix   Infinix Hot      (Aegean Blue          Helio G35 Processor
# 3     realme  realme Narzo      (Laser Black          Helio G85 Processor
# 4     realme  realme Narzo      (Laser Black          Helio G85 Processor
# ..       ...           ...               ...                          ...
# 547   GIONEE    GIONEE Max               NaN   BatteryOcta Core Processor
# 548   realme    realme C12       (Power Blue          Helio G35 Processor
# 549    REDMI       REDMI 9   (Electric Green     Snapdragon 662 Processor
# 550   realme    realme C25      (Watery Blue          Helio G70 Processor
# 551     POCO       POCO M3        (Cool Blue     Snapdragon 662 Processor
#
#      RAM_in_GB  ROM_in_GB Expandable_Memory  Battery_in_mAh         Camera  \
# ...

# %%
df.describe()
# Out:
#         RAM_in_GB   ROM_in_GB  Battery_in_mAh  Display_in_cm      Rating  \
# count  552.000000  552.000000      552.000000     552.000000  552.000000
# mean     3.742754   54.782609     5621.376812      16.596196    4.336413
# std      1.095670   22.116582      485.483937       0.352117    0.071006
# min      2.000000   32.000000     5000.000000      15.490000    4.100000
# 25%      3.000000   32.000000     5000.000000      16.510000    4.300000
# 50%      4.000000   64.000000     6000.000000      16.550000    4.300000
# 75%      4.000000   64.000000     6000.000000      16.590000    4.400000
# max      6.000000  128.000000     6000.000000      17.320000    4.400000
#
#               Price
# count    552.000000
# mean    8829.797101
# std     1471.370122
# min     5499.000000
# 25%     7999.000000
# 50%     8499.000000
# 75%     9624.000000
# max    11999.000000

# %%
df.isnull().sum()
# Out:
# Brand                 0
# Model_Name            0
# colour               48
# Processor             0
# RAM_in_GB             0
# ROM_in_GB             0
# Expandable_Memory    23
# Battery_in_mAh        0
# Camera                0
# Display_in_cm         0
# Rating                0
# Price                 0
# dtype: int64

# %% [markdown]
# #### Here in our dataset we found some null values if we consider null values then this may affect our analysis

# %% [markdown]
# #### So in order to overcome these null values and getting faulty data I'm trying to use fillna or drop method depending on our requirements.

# %% [markdown]
# ## Using fillna I have filled the null values and now our data is fully cleaned

# %%
df["colour"].fillna("Cool Blue",inplace=True)

# %%
df["Expandable_Memory"].fillna("256GB",inplace=True)

# %%
df.isnull().sum()
# Out:
# Brand                0
# Model_Name           0
# colour               0
# Processor            0
# RAM_in_GB            0
# ROM_in_GB            0
# Expandable_Memory    0
# Battery_in_mAh       0
# Camera               0
# Display_in_cm        0
# Rating               0
# Price                0
# dtype: int64

# %% [markdown]
# # Visualization

# %% [markdown]
# ## `Uni-Variate Analysis`

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'RAM_in_GB'}>,
#         <AxesSubplot:title={'center':'ROM_in_GB'}>],
#        [<AxesSubplot:title={'center':'Battery_in_mAh'}>,
#         <AxesSubplot:title={'center':'Display_in_cm'}>],
#        [<AxesSubplot:title={'center':'Rating'}>,
#         <AxesSubplot:title={'center':'Price'}>]], dtype=object)

# %%
df.hist(bins=15,color='red',edgecolor='black',grid=False)
rt =plt.suptitle('Mobile Univariate using histogram',x=0.65,y=1.25,fontsize=14)
plt.tight_layout(rect=(0,0,1.2,1.2))

# %%
sns.distplot(df["RAM_in_GB"])
# Out:
# <AxesSubplot:xlabel='RAM_in_GB', ylabel='Density'>

# %%
sns.distplot(df["ROM_in_GB"])
# Out:
# <AxesSubplot:xlabel='ROM_in_GB', ylabel='Density'>

# %%
sns.distplot(df["Display_in_cm"])
# Out:
# <AxesSubplot:xlabel='Display_in_cm', ylabel='Density'>

# %%
sns.distplot(df["Rating"])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Density'>

# %%
sns.distplot(df["Price"])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
sns.distplot(df["RAM_in_GB"],kde=False,rug=True)
# Out:
# <AxesSubplot:xlabel='RAM_in_GB'>

# %%
sns.distplot(df["ROM_in_GB"],kde=False,rug=True)
# Out:
# <AxesSubplot:xlabel='ROM_in_GB'>

# %%
sns.distplot(df["Display_in_cm"],kde=False,rug=True)
# Out:
# <AxesSubplot:xlabel='Display_in_cm'>

# %%
sns.distplot(df["Rating"],kde=False,rug=True)
# Out:
# <AxesSubplot:xlabel='Rating'>

# %%
sns.distplot(df["Price"],kde=False,rug=True)
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
sns.distplot(df["Rating"],hist=False,rug=True)
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Density'>

# %%
sns.distplot(df["Price"],hist=False,rug=True)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
sns.distplot(df["RAM_in_GB"],hist=False,rug=True)
# Out:
# <AxesSubplot:xlabel='RAM_in_GB', ylabel='Density'>

# %%
sns.distplot(df["ROM_in_GB"],hist=False,rug=True)
# Out:
# <AxesSubplot:xlabel='ROM_in_GB', ylabel='Density'>

# %%
sns.distplot(df["Display_in_cm"],hist=False,rug=True)
# Out:
# <AxesSubplot:xlabel='Display_in_cm', ylabel='Density'>

# %%
sns.barplot(x="Brand",y="RAM_in_GB",data=df)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='RAM_in_GB'>

# %%
sns.barplot(x="Brand",y="ROM_in_GB",data=df)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='ROM_in_GB'>

# %%
sns.barplot(x="Brand",y="Battery_in_mAh",data=df)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Battery_in_mAh'>

# %%
sns.barplot(x="Brand",y="Display_in_cm",data=df)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Display_in_cm'>

# %%
sns.barplot(x="Brand",y="Rating",data=df)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Rating'>

# %%
sns.barplot(x="Brand",y="Price",data=df)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Price'>

# %%
sns.countplot(x="Brand",data=df,palette="Greens_d")
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='count'>

# %%
plt.figure(figsize=(20,5))
sns.countplot(x="Model_Name",data=df,palette="Greens_d")
# Out:
# <AxesSubplot:xlabel='Model_Name', ylabel='count'>

# %%
plt.figure(figsize=(20,5))
sns.countplot(x="Processor",data=df,palette="Greens_d")
# Out:
# <AxesSubplot:xlabel='Processor', ylabel='count'>

# %%
sns.countplot(x="RAM_in_GB",data=df,palette="Greens_d")
# Out:
# <AxesSubplot:xlabel='RAM_in_GB', ylabel='count'>

# %%
sns.countplot(x="ROM_in_GB",data=df,palette="Greens_d")
# Out:
# <AxesSubplot:xlabel='ROM_in_GB', ylabel='count'>

# %%
sns.countplot(x="Expandable_Memory",data=df,palette="Greens_d")
# Out:
# <AxesSubplot:xlabel='Expandable_Memory', ylabel='count'>

# %%
sns.countplot(x="Battery_in_mAh",data=df,palette="Greens_d")
# Out:
# <AxesSubplot:xlabel='Battery_in_mAh', ylabel='count'>

# %%
sns.countplot(x="Display_in_cm",data=df,palette="Greens_d")
# Out:
# <AxesSubplot:xlabel='Display_in_cm', ylabel='count'>

# %%
plt.figure(figsize=(20,5))
sns.countplot(x="Camera",data=df,palette="Greens_d")
# Out:
# <AxesSubplot:xlabel='Camera', ylabel='count'>

# %%
sns.countplot(x="Rating",data=df,palette="Greens_d")
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='count'>

# %%
plt.figure(figsize=(20,5))
sns.countplot(x="Price",data=df,palette="Greens_d")
# Out:
# <AxesSubplot:xlabel='Price', ylabel='count'>

# %% [markdown]
# #### Here I can say from above uni-variate analysis performed using different variables using different graphs are as follows:-
# #### From Histogram we can see how our data has been distributed.
# #### From Barplot we can find out which has brand ,Model,processor have highest features.
# #### From countplot we can view our categorical data on each observations.
# #### From Distplot we can view how our data has been distributed against density distribution

# %% [markdown]
# ## `Bi-Variate Analysis`

# %%
sns.scatterplot(data=df, x="Brand", y="RAM_in_GB",hue="Price")
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='RAM_in_GB'>

# %%
sns.scatterplot(data=df, x="Brand", y="ROM_in_GB",hue="Price")
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='ROM_in_GB'>

# %%
sns.scatterplot(data=df, x="Brand", y="Battery_in_mAh",hue="Price")
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Battery_in_mAh'>

# %%
sns.scatterplot(data=df, x="Brand", y="Expandable_Memory",hue="Price")
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Expandable_Memory'>

# %%
sns.scatterplot(data=df, x="Brand", y="Camera",hue="Price")
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Camera'>

# %%
sns.scatterplot(data=df, x="Brand", y="Display_in_cm",hue="Price")
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Display_in_cm'>

# %%
sns.scatterplot(data=df, x="Brand", y="Rating",hue="Price")
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Rating'>

# %%
sns.scatterplot(data=df, x="Brand", y="Price",hue="Price")
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Price'>

# %%
plt.figure(figsize=(12,6))

plt.subplot(121)
sns.barplot(x="Brand",y="Price",data=df)
plt.title("Avg Price")

plt.subplot(122)
sns.barplot(x="Brand",y="RAM_in_GB",data=df,estimator=np.median)
plt.title("Median RAM_in_GB")
# Out:
# Text(0.5, 1.0, 'Median RAM_in_GB')

# %%
plt.figure(figsize=(12,6))

plt.subplot(121)
sns.barplot(x="Brand",y="Price",data=df)
plt.title("Avg Price")

plt.subplot(122)
sns.barplot(x="Brand",y="ROM_in_GB",data=df,estimator=np.median)
plt.title("Median ROM_in_GB")
# Out:
# Text(0.5, 1.0, 'Median ROM_in_GB')

# %%
plt.figure(figsize=(12,6))

plt.subplot(121)
sns.barplot(x="Brand",y="Price",data=df)
plt.title("Avg Price")

plt.subplot(122)
sns.barplot(x="Brand",y="Display_in_cm",data=df,estimator=np.median)
plt.title("Median Dispaly_in_cm")
# Out:
# Text(0.5, 1.0, 'Median Dispaly_in_cm')

# %%
plt.figure(figsize=(12,6))

plt.subplot(121)
sns.barplot(x="Brand",y="Price",data=df)
plt.title("Avg Price")

plt.subplot(122)
sns.barplot(x="Brand",y="Rating",data=df,estimator=np.median)
plt.title("Median Rating")
# Out:
# Text(0.5, 1.0, 'Median Rating')

# %%
plt.figure(figsize=(12,6))

plt.subplot(121)
sns.barplot(x="Expandable_Memory",y="Price",data=df)
plt.title("Avg Price")

plt.subplot(122)
sns.barplot(x="Expandable_Memory",y="Rating",data=df,estimator=np.median)
plt.title("Median Rating")
# Out:
# Text(0.5, 1.0, 'Median Rating')

# %%
plt.figure(figsize=(12,6))

plt.subplot(121)
sns.barplot(x="Expandable_Memory",y="Price",data=df)
plt.title("Avg Price")

plt.subplot(122)
sns.barplot(x="Expandable_Memory",y="RAM_in_GB",data=df,estimator=np.median)
plt.title("Median Rating")
# Out:
# Text(0.5, 1.0, 'Median Rating')

# %%
plt.figure(figsize=(12,6))

plt.subplot(121)
sns.barplot(x="Expandable_Memory",y="Price",data=df)
plt.title("Avg Price")

plt.subplot(122)
sns.barplot(x="Expandable_Memory",y="ROM_in_GB",data=df,estimator=np.median)
plt.title("Median Rating")
# Out:
# Text(0.5, 1.0, 'Median Rating')

# %%
plt.figure(figsize=(12,6))

plt.subplot(121)
sns.barplot(x="Expandable_Memory",y="Price",data=df)
plt.title("Avg Price")

plt.subplot(122)
sns.barplot(x="Expandable_Memory",y="Display_in_cm",data=df,estimator=np.median)
plt.title("Median Rating")
# Out:
# Text(0.5, 1.0, 'Median Rating')

# %%
sns.barplot(x="Brand",y="RAM_in_GB",hue="Price",data=df)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='RAM_in_GB'>

# %%
sns.barplot(x="Brand",y="ROM_in_GB",hue="Price",data=df)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='ROM_in_GB'>

# %%
sns.barplot(x="Brand",y="Display_in_cm",hue="Price",data=df)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Display_in_cm'>

# %%
sns.barplot(x="Brand",y="Battery_in_mAh",hue="Price",data=df)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Battery_in_mAh'>

# %%
sns.barplot(x="Brand",y="Rating",hue="Price",data=df)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Rating'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="Model_Name",y="RAM_in_GB",hue="Price",data=df)
# Out:
# <AxesSubplot:xlabel='Model_Name', ylabel='RAM_in_GB'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="Model_Name",y="ROM_in_GB",hue="Price",data=df)
# Out:
# <AxesSubplot:xlabel='Model_Name', ylabel='ROM_in_GB'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="Model_Name",y="Battery_in_mAh",hue="Price",data=df)
# Out:
# <AxesSubplot:xlabel='Model_Name', ylabel='Battery_in_mAh'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="Model_Name",y="Display_in_cm",hue="Price",data=df)
# Out:
# <AxesSubplot:xlabel='Model_Name', ylabel='Display_in_cm'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="Model_Name",y="Rating",hue="Price",data=df)
# Out:
# <AxesSubplot:xlabel='Model_Name', ylabel='Rating'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="Processor",y="Rating",hue="Price",data=df)
# Out:
# <AxesSubplot:xlabel='Processor', ylabel='Rating'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="Processor",y="Display_in_cm",hue="Price",data=df)
# Out:
# <AxesSubplot:xlabel='Processor', ylabel='Display_in_cm'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="Processor",y="Battery_in_mAh",hue="Price",data=df)
# Out:
# <AxesSubplot:xlabel='Processor', ylabel='Battery_in_mAh'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="Processor",y="ROM_in_GB",hue="Price",data=df)
# Out:
# <AxesSubplot:xlabel='Processor', ylabel='ROM_in_GB'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="Processor",y="RAM_in_GB",hue="Price",data=df)
# Out:
# <AxesSubplot:xlabel='Processor', ylabel='RAM_in_GB'>

# %%
sns.barplot(x="Brand",y="Price",hue="Rating",data=df)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Price'>

# %%
sns.barplot(x="Brand",y="Battery_in_mAh",hue="Rating",data=df)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Battery_in_mAh'>

# %%
sns.barplot(x="Brand",y="Display_in_cm",hue="Rating",data=df)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Display_in_cm'>

# %%
sns.barplot(x="Brand",y="RAM_in_GB",hue="Rating",data=df)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='RAM_in_GB'>

# %%
sns.barplot(x="Brand",y="ROM_in_GB",hue="Rating",data=df)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='ROM_in_GB'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="Model_Name",y="RAM_in_GB",hue="Rating",data=df)
# Out:
# <AxesSubplot:xlabel='Model_Name', ylabel='RAM_in_GB'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="Model_Name",y="ROM_in_GB",hue="Rating",data=df)
# Out:
# <AxesSubplot:xlabel='Model_Name', ylabel='ROM_in_GB'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="Model_Name",y="Battery_in_mAh",hue="Rating",data=df)
# Out:
# <AxesSubplot:xlabel='Model_Name', ylabel='Battery_in_mAh'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="Model_Name",y="Display_in_cm",hue="Rating",data=df)
# Out:
# <AxesSubplot:xlabel='Model_Name', ylabel='Display_in_cm'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="Model_Name",y="Price",hue="Rating",data=df)
# Out:
# <AxesSubplot:xlabel='Model_Name', ylabel='Price'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="Processor",y="Price",hue="Rating",data=df)
# Out:
# <AxesSubplot:xlabel='Processor', ylabel='Price'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="Processor",y="Display_in_cm",hue="Rating",data=df)
# Out:
# <AxesSubplot:xlabel='Processor', ylabel='Display_in_cm'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="Processor",y="Battery_in_mAh",hue="Rating",data=df)
# Out:
# <AxesSubplot:xlabel='Processor', ylabel='Battery_in_mAh'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="Processor",y="ROM_in_GB",hue="Rating",data=df)
# Out:
# <AxesSubplot:xlabel='Processor', ylabel='ROM_in_GB'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="Processor",y="RAM_in_GB",hue="Rating",data=df)
# Out:
# <AxesSubplot:xlabel='Processor', ylabel='RAM_in_GB'>

# %%
ax = sns.boxplot(x=df["ROM_in_GB"])

# %%
ax = sns.boxplot(x=df["Price"])

# %%
ax = sns.boxplot(x=df["Display_in_cm"])

# %%
ax = sns.boxplot(x=df["Rating"])

# %%
ax = sns.boxplot(x=df["RAM_in_GB"])

# %%
sns.boxplot(x="Brand",y="Display_in_cm",data=df)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Display_in_cm'>

# %%
sns.boxplot(x="Brand",y="Price",data=df)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Price'>

# %%
sns.boxplot(x="Brand",y="ROM_in_GB",data=df)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='ROM_in_GB'>

# %%
sns.boxplot(x="Expandable_Memory",y="Price",data=df)
# Out:
# <AxesSubplot:xlabel='Expandable_Memory', ylabel='Price'>

# %%
f ,(ax1,ax2) = plt.subplots(1,2,figsize=(10,5))
f.suptitle('Mobile Brand,Memory,Display')

sns.boxplot(x='RAM_in_GB',y='Brand',data=df,ax=ax1)
ax1.set_xlabel("RAM_in-GB",size=15,alpha=1.0)
ax1.set_ylabel("Brand",size=15,alpha=1.0)

sns.boxplot(x='Display_in_cm',y='Brand',data=df,ax=ax2)
ax2.set_xlabel("Display_in_cm",size=15,alpha=1.0)
ax2.set_ylabel("Brand",size=15,alpha=1.0)
# Out:
# Text(0, 0.5, 'Brand')

# %%
sns.boxplot(x="Brand",y="RAM_in_GB",data=df)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='RAM_in_GB'>

# %%
f ,(ax1,ax2) = plt.subplots(1,2,figsize=(10,5))
f.suptitle('Mobile Brand,Storage,Display')

sns.boxplot(x='ROM_in_GB',y='Brand',data=df,ax=ax1)
ax1.set_xlabel("ROM_in-GB",size=15,alpha=1.5)
ax1.set_ylabel("Brand",size=15,alpha=1.5)

sns.boxplot(x='Display_in_cm',y='Brand',data=df,ax=ax2)
ax2.set_xlabel("Display_in_cm",size=15,alpha=1.5)
ax2.set_ylabel("Brand",size=15,alpha=1.5)
# Out:
# Text(0, 0.5, 'Brand')

# %%
f ,(ax1,ax2) = plt.subplots(1,2,figsize=(10,5))
f.suptitle('Mobile Brand,Display,Ratings')

sns.boxplot(x='Display_in_cm',y='Brand',data=df,ax=ax1)
ax1.set_xlabel("Display_in_cm",size=15,alpha=1.5)
ax1.set_ylabel("Brand",size=15,alpha=1.5)

sns.boxplot(x='Rating',y='Brand',data=df,ax=ax2)
ax2.set_xlabel("Rating",size=15,alpha=1.5)
ax2.set_ylabel("Brand",size=15,alpha=1.5)
# Out:
# Text(0, 0.5, 'Brand')

# %%
f ,(ax1,ax2) = plt.subplots(1,2,figsize=(10,5))
f.suptitle('Mobile Brand,Display,Ratings')

sns.boxplot(x='Display_in_cm',y='Brand',data=df,ax=ax1)
ax1.set_xlabel("Display_in_cm",size=15,alpha=1.5)
ax1.set_ylabel("Brand",size=15,alpha=1.5)

sns.boxplot(x='Price',y='Brand',data=df,ax=ax2)
ax2.set_xlabel("Price",size=15,alpha=1.5)
ax2.set_ylabel("Brand",size=15,alpha=1.5)
# Out:
# Text(0, 0.5, 'Brand')

# %%
f ,(ax1,ax2) = plt.subplots(1,2,figsize=(10,5))
f.suptitle('Mobile Processor,Display,Ratings')

sns.boxplot(x='Display_in_cm',y='Processor',data=df,ax=ax1)
ax1.set_xlabel("Display_in_cm",size=15,alpha=1.5)
ax1.set_ylabel("Brand",size=15,alpha=1.5)

sns.boxplot(x='Price',y='Processor',data=df,ax=ax2)
ax2.set_xlabel("Price",size=15,alpha=1.5)
ax2.set_ylabel("Brand",size=15,alpha=1.5)
# Out:
# Text(0, 0.5, 'Brand')

# %%
ax = sns.boxplot(x="Brand", y="Price", hue="Rating",data=df,linewidth=2.5)

# %%
ax = sns.boxplot(x="Brand", y="Price", hue="Rating",
                 data=df, dodge=False)

# %%
sns.jointplot(x="Brand",y="RAM_in_GB",kind="scatter",data=df)

# %%
sns.jointplot(x="Price",y="ROM_in_GB",kind="scatter",data=df)

# %%
sns.jointplot(x="Price",y="ROM_in_GB",kind="hex",data=df,color="k")

# %%
ax = sns.swarmplot(x="Brand", y="Price", data=df, color="0.20")

# %%
ax = sns.swarmplot(x="Brand", y="RAM_in_GB", data=df, color="0.20")

# %%
ax = sns.swarmplot(x="Brand", y="ROM_in_GB", data=df, color="0.20")

# %%
ax = sns.swarmplot(x="Brand", y="Display_in_cm", data=df, color="0.20")

# %%
ax = sns.swarmplot(x="Brand", y="Battery_in_mAh", data=df, color="0.20")

# %%
ax = sns.swarmplot(x="Brand", y="Camera", data=df, color="0.20")

# %%
sns.catplot(x="RAM_in_GB",y="Price",data=df,hue="Brand",kind="violin")

# %%
sns.catplot(x="ROM_in_GB",y="Price",data=df,hue="Brand",kind="violin")

# %%
sns.catplot(x="Battery_in_mAh",y="Price",hue='Brand',kind='violin',data=df)

# %%
sns.catplot(x="Rating",y="Price",hue='Brand',kind='violin',data=df)

# %%
ax = sns.violinplot(x="Brand", y="RAM_in_GB", data=df)

# %%
ax = sns.violinplot(x="Brand", y="ROM_in_GB", data=df)

# %%
ax = sns.violinplot(x="Brand", y="Battery_in_mAh", data=df)

# %%
ax = sns.violinplot(x="Brand", y="Display_in_cm", data=df)

# %%
ax = sns.violinplot(x="Brand", y="Rating", data=df)

# %%
ax = sns.violinplot(x="Brand", y="Price", data=df)

# %%
sns.stripplot(data=df,x="Brand",y="RAM_in_GB")
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='RAM_in_GB'>

# %%
sns.stripplot(data=df,x="Brand",y="ROM_in_GB")
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='ROM_in_GB'>

# %%
sns.stripplot(data=df,x="Brand",y="Display_in_cm")
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Display_in_cm'>

# %%
sns.stripplot(data=df,x="Brand",y="Rating")
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Rating'>

# %%
sns.stripplot(data=df,x="Brand",y="Price")
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Price'>

# %% [markdown]
# #### Here I can say from above Bi-variate analysis performed using different variables using different graphs are as follows:-
# #### From Scatter plot we can see how our data has been distributed.
# #### From Barplot we can find out which has brand ,Model,processor have highest features.
# #### From catplot we can view relationship between a numerical and one or more categorical variables.
# #### From violinplot we can get distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared.

# %%
sns.pointplot(x='Brand',y='RAM_in_GB',data=df,color='#606060',alpha=0.8)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='RAM_in_GB'>

# %%
sns.pointplot(x='Brand',y='ROM_in_GB',data=df,color='#606060',alpha=0.8)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='ROM_in_GB'>

# %%
sns.pointplot(x='Brand',y='Battery_in_mAh',data=df,color='#606060',alpha=0.8)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Battery_in_mAh'>

# %%
sns.pointplot(x='Brand',y='Display_in_cm',data=df,color='#606060',alpha=0.8)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Display_in_cm'>

# %%
sns.pointplot(x='Brand',y='Rating',data=df,color='#606060',alpha=0.8)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Rating'>

# %%
sns.pointplot(x='Brand',y='Price',data=df,color='#606060',alpha=0.8)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Price'>

# %% [markdown]
# ## `Multi-Variate Analysis`

# %%
f ,ax = plt.subplots(figsize=(10,6))
corr = df.corr()
hm = sns.heatmap(round(corr,2),annot=True,ax=ax,cmap="coolwarm")
t = f.suptitle('Mobile Data Correlation Heatmap',fontsize=14)

# %%
sns.pairplot(df,hue='Price',diag_kind='kde',kind='scatter')

# %%
plt.figure(figsize=(10,5))
sns.pairplot(df)

# %%
sns.pairplot(df,hue="Brand")

# %%
sns.pairplot(df,hue="Model_Name")

# %%
sns.pairplot(df,hue="Price")

# %%
sns.pairplot(df,hue="Rating")

# %%
sns.pairplot(df,hue="Display_in_cm")

# %%
sns.pairplot(df,hue="Camera")

# %%
sns.pairplot(df,hue="ROM_in_GB")

# %%
sns.pairplot(df,hue="RAM_in_GB")

# %%
sns.pairplot(df,hue="Processor")

# %% [markdown]
# #### Here I can say from above Multi-variate analysis performed using different variables using different graphs are as follows:-
# #### From heatmap we can see how our data is correlated where darker colour represents the values of a particular variable are strongly correlated and where as on other hand lighter shade indicates they are lightly correlated or the correlation between them are absent.
# #### Even we can say darker shades are positively correlated and lighter shades indicates negatively correlated.
# #### pairplot allows us to look at the diagonal distribution of our data.

# %% [markdown]
# # `Conclusion`

# %% [markdown]
# ## Overall from above analysis from mobile data set I conclude that mobiles with following features:-
# ### RAM=4-6GB
# ### ROM=64GB
# ### Display=16.59cm
# ### camera=48MP2MP2MP8MP
# ### Battery=5,500 to 6000mAh
# ### Rating=4.3
# ### Price=8,500 to 12,000
# ### Processor=Snapdragon 662,Helio G85
#
# ### These mobiles are having awesome performance compared to other models in gaming aspect as well as for general use we can go with these features while buying a new mobile.
#
# ## Future Scope:-
#
# ### In future keeping this data in reference we can build a better model than the present one and increase it's performance more than as now we are viewing.
